# %% [markdown]
# <a href="https://colab.research.google.com/github/msrosyabreu/PROJECTS-RA/blob/main/PythonProject2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

df = pd.read_csv('https://raw.githubusercontent.com/niteen11/DataAnalyticsAcademy/master/Python/dataset_diabetes/diabetic_data.csv')

#Below's function shows the first 10 rows of the dataframe, useful to see some of the data.
df.head(10)
# Out:
#    encounter_id  patient_nbr             race  ... change diabetesMed readmitted
# 0       2278392      8222157        Caucasian  ...     No          No         NO
# 1        149190     55629189        Caucasian  ...     Ch         Yes        >30
# 2         64410     86047875  AfricanAmerican  ...     No         Yes         NO
# 3        500364     82442376        Caucasian  ...     Ch         Yes         NO
# 4         16680     42519267        Caucasian  ...     Ch         Yes         NO
# 5         35754     82637451        Caucasian  ...     No         Yes        >30
# 6         55842     84259809        Caucasian  ...     Ch         Yes         NO
# 7         63768    114882984        Caucasian  ...     No         Yes        >30
# 8         12522     48330783        Caucasian  ...     Ch         Yes         NO
# 9         15738     63555939        Caucasian  ...     Ch         Yes         NO
#
# [10 rows x 50 columns]

# %%
#Below's helpful function calculates / summarizes some statistical data like percentile, mean and other values from the dataframe. 
df.describe()
# Out:
#        encounter_id   patient_nbr  ...  number_inpatient  number_diagnoses
# count  1.017660e+05  1.017660e+05  ...     101766.000000     101766.000000
# mean   1.652016e+08  5.433040e+07  ...          0.635566          7.422607
# std    1.026403e+08  3.869636e+07  ...          1.262863          1.933600
# min    1.252200e+04  1.350000e+02  ...          0.000000          1.000000
# 25%    8.496119e+07  2.341322e+07  ...          0.000000          6.000000
# 50%    1.523890e+08  4.550514e+07  ...          0.000000          8.000000
# 75%    2.302709e+08  8.754595e+07  ...          1.000000          9.000000
# max    4.438672e+08  1.895026e+08  ...         21.000000         16.000000
#
# [8 rows x 13 columns]

# %%
drop_cols = ['weight', 'payer_code']
df.drop(drop_cols, inplace=True, axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-5c59e77e0509> in <module>()
#       1 drop_cols = ['weight', 'payer_code']
# ----> 2 df.drop(drop_cols, inplace=True, axis=1)
#
# NameError: name 'df' is not defined

# %%
#Below's function shows the series of the data type of each column, like int64, object, etc.
df.dtypes
# Out:
# encounter_id                 int64
# patient_nbr                  int64
# race                        object
# gender                      object
# age                         object
# weight                      object
# admission_type_id            int64
# discharge_disposition_id     int64
# admission_source_id          int64
# time_in_hospital             int64
# payer_code                  object
# medical_specialty           object
# num_lab_procedures           int64
# num_procedures               int64
# num_medications              int64
# number_outpatient            int64
# number_emergency             int64
# number_inpatient             int64
# diag_1                      object
# diag_2                      object
# diag_3                      object
# number_diagnoses             int64
# max_glu_serum               object
# A1Cresult                   object
# metformin                   object
# repaglinide                 object
# nateglinide                 object
# ...

# %%
#Below's function is used to print/show a concise summary/info of the dataframe, like data types, non-null values, count, and etc.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101766 entries, 0 to 101765
# Data columns (total 50 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   encounter_id              101766 non-null  int64
#  1   patient_nbr               101766 non-null  int64
#  2   race                      101766 non-null  object
#  3   gender                    101766 non-null  object
#  4   age                       101766 non-null  object
#  5   weight                    101766 non-null  object
#  6   admission_type_id         101766 non-null  int64
#  7   discharge_disposition_id  101766 non-null  int64
#  8   admission_source_id       101766 non-null  int64
#  9   time_in_hospital          101766 non-null  int64
#  10  payer_code                101766 non-null  object
#  11  medical_specialty         101766 non-null  object
#  12  num_lab_procedures        101766 non-null  int64
# ...

# %%
#Below's function is used to remove and analyze rows or columns. 
df.dropna()
# Out:
#         encounter_id  patient_nbr  ... diabetesMed readmitted
# 0            2278392      8222157  ...          No         NO
# 1             149190     55629189  ...         Yes        >30
# 2              64410     86047875  ...         Yes         NO
# 3             500364     82442376  ...         Yes         NO
# 4              16680     42519267  ...         Yes         NO
# ...              ...          ...  ...         ...        ...
# 101761     443847548    100162476  ...         Yes        >30
# 101762     443847782     74694222  ...         Yes         NO
# 101763     443854148     41088789  ...         Yes         NO
# 101764     443857166     31693671  ...         Yes         NO
# 101765     443867222    175429310  ...          No         NO
#
# [101766 rows x 50 columns]

# %%
#checking if the index is unique
df['encounter_id'].is_unique
# Out:
# True

# %%
#setting the new index, removed the 0,1,2,3 and set the unique index of using encounter_id.
df=df.set_index('encounter_id')
df.head()
# Out:
#               patient_nbr             race  ... diabetesMed readmitted
# encounter_id                                ...
# 2278392           8222157        Caucasian  ...          No         NO
# 149190           55629189        Caucasian  ...         Yes        >30
# 64410            86047875  AfricanAmerican  ...         Yes         NO
# 500364           82442376        Caucasian  ...         Yes         NO
# 16680            42519267        Caucasian  ...         Yes         NO
#
# [5 rows x 49 columns]

# %%
#the below function splitted the data selected which is gender and number_diagnoses to help compare results on particular data. Here we can see there were more females diagnosed with diabetes than males.
df.groupby(['gender'])['number_diagnoses'].count()
# Out:
# gender
# Female             54708
# Male               47055
# Unknown/Invalid        3
# Name: number_diagnoses, dtype: int64

# %%
#the below function filtered the data to be looked at by the ages between 70-80.
df[df['age'].str.contains('70-80')]
# Out:
#               patient_nbr             race  ... diabetesMed readmitted
# encounter_id                                ...
# 63768           114882984        Caucasian  ...         Yes        >30
# 89682           107389323  AfricanAmerican  ...         Yes        >30
# 148530           69422211                ?  ...         Yes         NO
# 182796           63000108  AfricanAmerican  ...          No         NO
# 216156           62718876  AfricanAmerican  ...         Yes         NO
# ...                   ...              ...  ...         ...        ...
# 443842016       183087545        Caucasian  ...         Yes        >30
# 443842136       181593374        Caucasian  ...         Yes         NO
# 443847548       100162476  AfricanAmerican  ...         Yes        >30
# 443854148        41088789        Caucasian  ...         Yes         NO
# 443867222       175429310        Caucasian  ...          No         NO
#
# [26068 rows x 49 columns]

# %%
#This shows the distribution of the numbers of meds.
sns.distplot(df['num_medications'], bins = 30)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#this visual represents races and compared it to number_diagnoses. We can see Caucasians had the highest diagnoses. 
sns.barplot(x = 'number_diagnoses' , y ='race' , data =df)

# %%
#this visual shows female, male and unknown and the recorded age brackets provided by the data. 
sns.stripplot(x='gender', y='age', data=df)

# %%
#this visual shows many comparisons. 
sns.pairplot(df)
